# %%
import airbnb_scraper.pyairbnb as pyairbnb
import pandas as pd
import time
import re
import csv

input_csv = r"C:\Users\fraxi\OneDrive\Desktop\code task\Amsterdam\transaction_pairs.csv"
output_csv = "B(k,·)_host_reviews_written.csv"
language = "en"
proxy_url = None  
delay_seconds = 1

# %%
df = pd.read_csv(input_csv)
listing_ids = df["listing_id"].dropna().astype(str).unique().tolist()
print(f"🔍 共获取 {len(listing_ids)} 个唯一 listing_id")

results = []

for idx, listing_id in enumerate(listing_ids, 1):
    room_url = f"https://www.airbnb.com/rooms/{listing_id}"
    print(f"\n🔹[{idx}/{len(listing_ids)}] 正在爬取房源 {listing_id}...")

    try:
        reviews = pyairbnb.get_reviews(room_url, language, proxy_url)
        for review in reviews:
            response = review.get("response")

           
            if not response and review.get("comments"):
                match = re.search(r"<br\s*/?>\s*(?:host\s*)?response\s*:?\s*(.*)", review["comments"], flags=re.IGNORECASE)
                if match:
                    response = match.group(1).strip()

            if response:
                results.append({
                    "review_id": review.get("id"),
                    "listing_id": listing_id,
                    "host_id": review.get("reviewee", {}).get("id"),
                    "created_at": review.get("createdAt"),
                    "response": response
                })

    except Exception as e:
        print(f"failed: {e}")


    time.sleep(delay_seconds)


if results:
    with open(output_csv, "w", newline='', encoding="utf-8-sig") as f:
        writer = csv.DictWriter(f, fieldnames=["review_id", "listing_id", "host_id", "created_at", "response"])
        writer.writeheader()
        writer.writerows(results)
    print(f" A total of {len(results)} reviews with host responses have been extracted and saved to: {output_csv}")
else:
    print(" No reviews contain host responses.")
# Out:
# 🔍 共获取 932 个唯一 listing_id
#
# 🔹[1/932] 正在爬取房源 27886...
# 🔹[2/932] 正在爬取房源 28871...
#
# 🔹[3/932] 正在爬取房源 29051...
#
# 🔹[4/932] 正在爬取房源 49552...
#
# 🔹[5/932] 正在爬取房源 50263...
#
# 🔹[6/932] 正在爬取房源 50515...
#
# 🔹[7/932] 正在爬取房源 50523...
#
# 🔹[8/932] 正在爬取房源 55709...
#
# 🔹[9/932] 正在爬取房源 55868...
#
# 🔹[10/932] 正在爬取房源 62015...
#
# 🔹[11/932] 正在爬取房源 80635...
#
# 🔹[12/932] 正在爬取房源 91535...
#
# 🔹[13/932] 正在爬取房源 137026...
#
# 🔹[14/932] 正在爬取房源 158633...
#
# 🔹[15/932] 正在爬取房源 168769...
#
# 🔹[16/932] 正在爬取房源 179528...
#
# 🔹[17/932] 正在爬取房源 188347...
#
# 🔹[18/932] 正在爬取房源 189754...
#
# 🔹[19/932] 正在爬取房源 190943...
#
# 🔹[20/932] 正在爬取房源 213371...
#
# 🔹[21/932] 正在爬取房源 214531...
#
# 🔹[22/932] 正在爬取房源 245927...
#
# 🔹[23/932] 正在爬取房源 247805...
#
# 🔹[24/932] 正在爬取房源 252080...
#
# 🔹[25/932] 正在爬取房源 254104...
#
# 🔹[26/932] 正在爬取房源 254800...
#
# 🔹[27/932] 正在爬取房源 255809...
#
# 🔹[28/932] 正在爬取房源 274706...
#
# 🔹[29/932] 正在爬取房源 283170...
#
# 🔹[30/932] 正在爬取房源 286500...
#
# 🔹[31/932] 正在爬取房源 290701...
#
# 🔹[32/932] 正在爬取房源 304082...
#
# 🔹[33/932] 正在爬取房源 306852...
#
# 🔹[34/932] 正在爬取房源 307497...
#
# 🔹[35/932] 正在爬取房源 307621...
#
# 🔹[36/932] 正在爬取房源 308028...
#
# 🔹[37/932] 正在爬取房源 311124...
#
# 🔹[38/932] 正在爬取房源 327285...
#
# 🔹[39/932] 正在爬取房源 331946...
#
# 🔹[40/932] 正在爬取房源 343094...
#
# 🔹[41/932] 正在爬取房源 357980...
#
# 🔹[42/932] 正在爬取房源 359298...
#
# 🔹[43/932] 正在爬取房源 366438...
#
# 🔹[44/932] 正在爬取房源 367107...
#
# 🔹[45/932] 正在爬取房源 379885...
#
# 🔹[46/932] 正在爬取房源 383182...
#
# 🔹[47/932] 正在爬取房源 414865...
#
# 🔹[48/932] 正在爬取房源 415619...
#
# 🔹[49/932] 正在爬取房源 440992...
#
# 🔹[50/932] 正在爬取房源 445660...
# ❌ 获取失败: Failed to perform, curl: (35) Recv failure: Connection was reset. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
#
# 🔹[51/932] 正在爬取房源 450767...
#
# 🔹[52/932] 正在爬取房源 462341...
#
# 🔹[53/932] 正在爬取房源 483779...
#
# 🔹[54/932] 正在爬取房源 505012...
#
# 🔹[55/932] 正在爬取房源 515749...
#
# 🔹[56/932] 正在爬取房源 515921...
#
# 🔹[57/932] 正在爬取房源 522471...
#
# 🔹[58/932] 正在爬取房源 528594...
#
# 🔹[59/932] 正在爬取房源 537321...
#
# 🔹[60/932] 正在爬取房源 549310...
#
# 🔹[61/932] 正在爬取房源 553514...
#
# 🔹[62/932] 正在爬取房源 556829...
#
# 🔹[63/932] 正在爬取房源 568446...
#
# 🔹[64/932] 正在爬取房源 570753...
#
# 🔹[65/932] 正在爬取房源 575603...
#
# 🔹[66/932] 正在爬取房源 575615...
#
# 🔹[67/932] 正在爬取房源 579851...
#
# 🔹[68/932] 正在爬取房源 582028...
#
# 🔹[69/932] 正在爬取房源 582382...
#
# 🔹[70/932] 正在爬取房源 588020...
#
# 🔹[71/932] 正在爬取房源 590236...
#
# 🔹[72/932] 正在爬取房源 591951...
#
# 🔹[73/932] 正在爬取房源 606871...
#
# 🔹[74/932] 正在爬取房源 608432...
#
# 🔹[75/932] 正在爬取房源 623123...
#
# 🔹[76/932] 正在爬取房源 627188...
#
# 🔹[77/932] 正在爬取房源 638555...
#
# 🔹[78/932] 正在爬取房源 654931...
#
# 🔹[79/932] 正在爬取房源 655216...
#
# 🔹[80/932] 正在爬取房源 660856...
#
# 🔹[81/932] 正在爬取房源 664697...
#
# 🔹[82/932] 正在爬取房源 683431...
#
# 🔹[83/932] 正在爬取房源 685990...
#
# 🔹[84/932] 正在爬取房源 689623...
#
# 🔹[85/932] 正在爬取房源 694850...
#
# 🔹[86/932] 正在爬取房源 696113...
#
# 🔹[87/932] 正在爬取房源 698672...
#
# 🔹[88/932] 正在爬取房源 702894...
#
# 🔹[89/932] 正在爬取房源 708528...
#
# 🔹[90/932] 正在爬取房源 716107...
#
# 🔹[91/932] 正在爬取房源 728144...
#
# 🔹[92/932] 正在爬取房源 729260...
#
# 🔹[93/932] 正在爬取房源 741043...
#
# 🔹[94/932] 正在爬取房源 742160...
#
# 🔹[95/932] 正在爬取房源 744659...
#
# 🔹[96/932] 正在爬取房源 746067...
#
# 🔹[97/932] 正在爬取房源 751626...
#
# 🔹[98/932] 正在爬取房源 754613...
#
# 🔹[99/932] 正在爬取房源 755431...
#
# 🔹[100/932] 正在爬取房源 758475...
#
# 🔹[101/932] 正在爬取房源 759060...
#
# 🔹[102/932] 正在爬取房源 759299...
#
# 🔹[103/932] 正在爬取房源 761411...
#
# 🔹[104/932] 正在爬取房源 768737...
#
# 🔹[105/932] 正在爬取房源 771217...
#
# 🔹[106/932] 正在爬取房源 771343...
#
# 🔹[107/932] 正在爬取房源 771758...
#
# 🔹[108/932] 正在爬取房源 775655...
#
# 🔹[109/932] 正在爬取房源 782254...
#
# 🔹[110/932] 正在爬取房源 794322...
#
# 🔹[111/932] 正在爬取房源 796683...
#
# 🔹[112/932] 正在爬取房源 800723...
#
# 🔹[113/932] 正在爬取房源 801544...
#
# 🔹[114/932] 正在爬取房源 802052...
#
# 🔹[115/932] 正在爬取房源 805330...
#
# 🔹[116/932] 正在爬取房源 816940...
#
# 🔹[117/932] 正在爬取房源 817716...
#
# 🔹[118/932] 正在爬取房源 818881...
#
# 🔹[119/932] 正在爬取房源 829306...
#
# 🔹[120/932] 正在爬取房源 834233...
#
# 🔹[121/932] 正在爬取房源 847093...
#
# 🔹[122/932] 正在爬取房源 851044...
#
# 🔹[123/932] 正在爬取房源 862411...
#
# 🔹[124/932] 正在爬取房源 865328...
#
# 🔹[125/932] 正在爬取房源 874076...
#
# 🔹[126/932] 正在爬取房源 877702...
#
# 🔹[127/932] 正在爬取房源 879986...
#
# 🔹[128/932] 正在爬取房源 890288...
#
# 🔹[129/932] 正在爬取房源 895684...
#
# 🔹[130/932] 正在爬取房源 901789...
#
# 🔹[131/932] 正在爬取房源 906446...
#
# 🔹[132/932] 正在爬取房源 916096...
#
# 🔹[133/932] 正在爬取房源 919131...
#
# 🔹[134/932] 正在爬取房源 931270...
#
# 🔹[135/932] 正在爬取房源 933523...
#
# 🔹[136/932] 正在爬取房源 934060...
#
# 🔹[137/932] 正在爬取房源 937635...
#
# 🔹[138/932] 正在爬取房源 946142...
# ❌ 获取失败: Failed to perform, curl: (56) Recv failure: Connection was reset. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
#
# 🔹[139/932] 正在爬取房源 947437...
#
# 🔹[140/932] 正在爬取房源 951483...
#
# 🔹[141/932] 正在爬取房源 954629...
#
# 🔹[142/932] 正在爬取房源 954633...
#
# 🔹[143/932] 正在爬取房源 957396...
#
# 🔹[144/932] 正在爬取房源 963328...
#
# 🔹[145/932] 正在爬取房源 964986...
#
# 🔹[146/932] 正在爬取房源 969862...
#
# 🔹[147/932] 正在爬取房源 978852...
#
# 🔹[148/932] 正在爬取房源 989222...
#
# 🔹[149/932] 正在爬取房源 995087...
#
# 🔹[150/932] 正在爬取房源 998822...
#
# 🔹[151/932] 正在爬取房源 1005026...
#
# 🔹[152/932] 正在爬取房源 1008006...
#
# 🔹[153/932] 正在爬取房源 1018639...
#
# 🔹[154/932] 正在爬取房源 1018703...
#
# 🔹[155/932] 正在爬取房源 1021538...
#
# 🔹[156/932] 正在爬取房源 1038120...
#
# 🔹[157/932] 正在爬取房源 1043348...
#
# 🔹[158/932] 正在爬取房源 1044448...
#
# 🔹[159/932] 正在爬取房源 1044452...
#
# 🔹[160/932] 正在爬取房源 1057494...
#
# 🔹[161/932] 正在爬取房源 1068565...
#
# 🔹[162/932] 正在爬取房源 1071414...
#
# 🔹[163/932] 正在爬取房源 1085099...
#
# 🔹[164/932] 正在爬取房源 1088859...
#
# 🔹[165/932] 正在爬取房源 1102846...
#
# 🔹[166/932] 正在爬取房源 1105128...
#
# 🔹[167/932] 正在爬取房源 1105924...
#
# 🔹[168/932] 正在爬取房源 1116446...
#
# 🔹[169/932] 正在爬取房源 1134823...
#
# 🔹[170/932] 正在爬取房源 1145140...
#
# 🔹[171/932] 正在爬取房源 1145866...
#
# 🔹[172/932] 正在爬取房源 1149289...
#
# 🔹[173/932] 正在爬取房源 1149380...
#
# 🔹[174/932] 正在爬取房源 1149694...
#
# 🔹[175/932] 正在爬取房源 1155386...
#
# 🔹[176/932] 正在爬取房源 1158865...
#
# 🔹[177/932] 正在爬取房源 1159534...
#
# 🔹[178/932] 正在爬取房源 1174506...
#
# 🔹[179/932] 正在爬取房源 1196088...
#
# 🔹[180/932] 正在爬取房源 1223171...
#
# 🔹[181/932] 正在爬取房源 1225622...
#
# 🔹[182/932] 正在爬取房源 1236227...
#
# 🔹[183/932] 正在爬取房源 1246242...
#
# 🔹[184/932] 正在爬取房源 1260229...
#
# 🔹[185/932] 正在爬取房源 1262157...
#
# 🔹[186/932] 正在爬取房源 1271700...
#
# 🔹[187/932] 正在爬取房源 1272352...
# ❌ 获取失败: list index out of range
#
# 🔹[188/932] 正在爬取房源 1299652...
#
# 🔹[189/932] 正在爬取房源 1303321...
#
# 🔹[190/932] 正在爬取房源 1331157...
#
# 🔹[191/932] 正在爬取房源 1338064...
#
# 🔹[192/932] 正在爬取房源 1350096...
#
# 🔹[193/932] 正在爬取房源 1350246...
#
# 🔹[194/932] 正在爬取房源 1358042...
#
# 🔹[195/932] 正在爬取房源 1366058...
#
# 🔹[196/932] 正在爬取房源 1383369...
#
# 🔹[197/932] 正在爬取房源 1394668...
#
# 🔹[198/932] 正在爬取房源 1397317...
#
# 🔹[199/932] 正在爬取房源 1402541...
#
# 🔹[200/932] 正在爬取房源 1408035...
#
# 🔹[201/932] 正在爬取房源 1429701...
#
# 🔹[202/932] 正在爬取房源 1432378...
#
# 🔹[203/932] 正在爬取房源 1443515...
#
# 🔹[204/932] 正在爬取房源 1447217...
#
# 🔹[205/932] 正在爬取房源 1454784...
#
# 🔹[206/932] 正在爬取房源 1468473...
#
# 🔹[207/932] 正在爬取房源 1482038...
#
# 🔹[208/932] 正在爬取房源 1482851...
#
# 🔹[209/932] 正在爬取房源 1484348...
#
# 🔹[210/932] 正在爬取房源 1505436...
#
# 🔹[211/932] 正在爬取房源 1511360...
#
# 🔹[212/932] 正在爬取房源 1521776...
#
# 🔹[213/932] 正在爬取房源 1524993...
#
# 🔹[214/932] 正在爬取房源 1532428...
#
# 🔹[215/932] 正在爬取房源 1534317...
#
# 🔹[216/932] 正在爬取房源 1534620...
#
# 🔹[217/932] 正在爬取房源 1537852...
#
# 🔹[218/932] 正在爬取房源 1558627...
#
# 🔹[219/932] 正在爬取房源 1567732...
#
# 🔹[220/932] 正在爬取房源 1567891...
#
# 🔹[221/932] 正在爬取房源 1580186...
#
# 🔹[222/932] 正在爬取房源 1586071...
#
# 🔹[223/932] 正在爬取房源 1601408...
#
# 🔹[224/932] 正在爬取房源 1605387...
#
# 🔹[225/932] 正在爬取房源 1620658...
#
# 🔹[226/932] 正在爬取房源 1630438...
#
# 🔹[227/932] 正在爬取房源 1630603...
#
# 🔹[228/932] 正在爬取房源 1662676...
#
# 🔹[229/932] 正在爬取房源 1708187...
#
# 🔹[230/932] 正在爬取房源 1708637...
#
# 🔹[231/932] 正在爬取房源 1713147...
#
# 🔹[232/932] 正在爬取房源 1723463...
#
# 🔹[233/932] 正在爬取房源 1723551...
#
# 🔹[234/932] 正在爬取房源 1733772...
#
# 🔹[235/932] 正在爬取房源 1734564...
#
# 🔹[236/932] 正在爬取房源 1734769...
#
# 🔹[237/932] 正在爬取房源 1767048...
#
# 🔹[238/932] 正在爬取房源 1771760...
#
# 🔹[239/932] 正在爬取房源 1783461...
#
# 🔹[240/932] 正在爬取房源 1786144...
#
# 🔹[241/932] 正在爬取房源 1793971...
#
# 🔹[242/932] 正在爬取房源 1797364...
#
# 🔹[243/932] 正在爬取房源 1798944...
#
# 🔹[244/932] 正在爬取房源 1814121...
#
# 🔹[245/932] 正在爬取房源 1830345...
#
# 🔹[246/932] 正在爬取房源 1831427...
#
# 🔹[247/932] 正在爬取房源 1849795...
#
# 🔹[248/932] 正在爬取房源 1859255...
#
# 🔹[249/932] 正在爬取房源 1863996...
#
# 🔹[250/932] 正在爬取房源 1886198...
#
# 🔹[251/932] 正在爬取房源 1889863...
#
# 🔹[252/932] 正在爬取房源 1894944...
#
# 🔹[253/932] 正在爬取房源 1901845...
#
# 🔹[254/932] 正在爬取房源 1904291...
#
# 🔹[255/932] 正在爬取房源 1911182...
#
# 🔹[256/932] 正在爬取房源 1912704...
#
# 🔹[257/932] 正在爬取房源 1919184...
#
# 🔹[258/932] 正在爬取房源 1927634...
#
# 🔹[259/932] 正在爬取房源 1938510...
#
# 🔹[260/932] 正在爬取房源 1943465...
#
# 🔹[261/932] 正在爬取房源 2005996...
#
# 🔹[262/932] 正在爬取房源 2015074...
#
# 🔹[263/932] 正在爬取房源 2016153...
#
# 🔹[264/932] 正在爬取房源 2018017...
#
# 🔹[265/932] 正在爬取房源 2070211...
#
# 🔹[266/932] 正在爬取房源 2074047...
#
# 🔹[267/932] 正在爬取房源 2084758...
#
# 🔹[268/932] 正在爬取房源 2090727...
#
# 🔹[269/932] 正在爬取房源 2097548...
#
# 🔹[270/932] 正在爬取房源 2144304...
#
# 🔹[271/932] 正在爬取房源 2148417...
#
# 🔹[272/932] 正在爬取房源 2175600...
#
# 🔹[273/932] 正在爬取房源 2224903...
#
# 🔹[274/932] 正在爬取房源 2234721...
#
# 🔹[275/932] 正在爬取房源 2235666...
#
# 🔹[276/932] 正在爬取房源 2272303...
#
# 🔹[277/932] 正在爬取房源 2336047...
#
# 🔹[278/932] 正在爬取房源 2368869...
#
# 🔹[279/932] 正在爬取房源 2400486...
#
# 🔹[280/932] 正在爬取房源 2429334...
#
# 🔹[281/932] 正在爬取房源 2435572...
#
# 🔹[282/932] 正在爬取房源 2450249...
#
# 🔹[283/932] 正在爬取房源 2471617...
#
# 🔹[284/932] 正在爬取房源 2477880...
#
# 🔹[285/932] 正在爬取房源 2478937...
#
# 🔹[286/932] 正在爬取房源 2480621...
#
# 🔹[287/932] 正在爬取房源 2497346...
#
# 🔹[288/932] 正在爬取房源 2514858...
#
# 🔹[289/932] 正在爬取房源 2518607...
#
# 🔹[290/932] 正在爬取房源 2529643...
#
# 🔹[291/932] 正在爬取房源 2534067...
#
# 🔹[292/932] 正在爬取房源 2534166...
#
# 🔹[293/932] 正在爬取房源 2574202...
#
# 🔹[294/932] 正在爬取房源 2623099...
#
# 🔹[295/932] 正在爬取房源 2639773...
#
# 🔹[296/932] 正在爬取房源 2647276...
#
# 🔹[297/932] 正在爬取房源 2648251...
#
# 🔹[298/932] 正在爬取房源 2704035...
#
# 🔹[299/932] 正在爬取房源 2705165...
#
# 🔹[300/932] 正在爬取房源 2708863...
#
# 🔹[301/932] 正在爬取房源 2761156...
#
# 🔹[302/932] 正在爬取房源 2763037...
#
# 🔹[303/932] 正在爬取房源 2763386...
#
# 🔹[304/932] 正在爬取房源 2775209...
#
# 🔹[305/932] 正在爬取房源 2780062...
#
# 🔹[306/932] 正在爬取房源 2787645...
#
# 🔹[307/932] 正在爬取房源 2800120...
#
# 🔹[308/932] 正在爬取房源 2809026...
#
# 🔹[309/932] 正在爬取房源 2829553...
#
# 🔹[310/932] 正在爬取房源 2830788...
#
# 🔹[311/932] 正在爬取房源 2842228...
#
# 🔹[312/932] 正在爬取房源 2853285...
#
# 🔹[313/932] 正在爬取房源 2861667...
#
# 🔹[314/932] 正在爬取房源 2902819...
#
# 🔹[315/932] 正在爬取房源 2912309...
#
# 🔹[316/932] 正在爬取房源 2942229...
#
# 🔹[317/932] 正在爬取房源 2965812...
#
# 🔹[318/932] 正在爬取房源 2976795...
#
# 🔹[319/932] 正在爬取房源 2981842...
#
# 🔹[320/932] 正在爬取房源 2981853...
#
# 🔹[321/932] 正在爬取房源 2981861...
#
# 🔹[322/932] 正在爬取房源 2981875...
# ❌ 获取失败: 'NoneType' object is not subscriptable
#
# 🔹[323/932] 正在爬取房源 2984018...
#
# 🔹[324/932] 正在爬取房源 3036359...
#
# 🔹[325/932] 正在爬取房源 3036789...
#
# 🔹[326/932] 正在爬取房源 3040900...
#
# 🔹[327/932] 正在爬取房源 3046271...
#
# 🔹[328/932] 正在爬取房源 3073208...
#
# 🔹[329/932] 正在爬取房源 3087967...
# ❌ 获取失败: Failed to perform, curl: (35) Recv failure: Connection was reset. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
#
# 🔹[330/932] 正在爬取房源 3099026...
#
# 🔹[331/932] 正在爬取房源 3111787...
#
# 🔹[332/932] 正在爬取房源 3120537...
#
# 🔹[333/932] 正在爬取房源 3155284...
#
# 🔹[334/932] 正在爬取房源 3172327...
#
# 🔹[335/932] 正在爬取房源 3180371...
#
# 🔹[336/932] 正在爬取房源 3225605...
#
# 🔹[337/932] 正在爬取房源 3235970...
#
# 🔹[338/932] 正在爬取房源 3254077...
#
# 🔹[339/932] 正在爬取房源 3270897...
#
# 🔹[340/932] 正在爬取房源 3282245...
#
# 🔹[341/932] 正在爬取房源 3285009...
#
# 🔹[342/932] 正在爬取房源 3308196...
#
# 🔹[343/932] 正在爬取房源 3322840...
#
# 🔹[344/932] 正在爬取房源 3329357...
#
# 🔹[345/932] 正在爬取房源 3346620...
#
# 🔹[346/932] 正在爬取房源 3352657...
#
# 🔹[347/932] 正在爬取房源 3383408...
#
# 🔹[348/932] 正在爬取房源 3388764...
#
# 🔹[349/932] 正在爬取房源 3428641...
#
# 🔹[350/932] 正在爬取房源 3432883...
# ❌ 获取失败: Failed to perform, curl: (56) Recv failure: Connection was reset. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
#
# 🔹[351/932] 正在爬取房源 3437329...
#
# 🔹[352/932] 正在爬取房源 3459981...
#
# 🔹[353/932] 正在爬取房源 3461086...
#
# 🔹[354/932] 正在爬取房源 3484708...
#
# 🔹[355/932] 正在爬取房源 3492282...
#
# 🔹[356/932] 正在爬取房源 3500433...
#
# 🔹[357/932] 正在爬取房源 3504128...
#
# 🔹[358/932] 正在爬取房源 3508800...
#
# 🔹[359/932] 正在爬取房源 3565477...
#
# 🔹[360/932] 正在爬取房源 3572825...
#
# 🔹[361/932] 正在爬取房源 3580990...
#
# 🔹[362/932] 正在爬取房源 3604547...
#
# 🔹[363/932] 正在爬取房源 3641710...
#
# 🔹[364/932] 正在爬取房源 3644360...
#
# 🔹[365/932] 正在爬取房源 3649382...
#
# 🔹[366/932] 正在爬取房源 3690880...
#
# 🔹[367/932] 正在爬取房源 3696035...
#
# 🔹[368/932] 正在爬取房源 3700218...
#
# 🔹[369/932] 正在爬取房源 3708105...
#
# 🔹[370/932] 正在爬取房源 3722301...
#
# 🔹[371/932] 正在爬取房源 3724060...
#
# 🔹[372/932] 正在爬取房源 3729980...
#
# 🔹[373/932] 正在爬取房源 3758059...
#
# 🔹[374/932] 正在爬取房源 3763507...
#
# 🔹[375/932] 正在爬取房源 3774247...
#
# 🔹[376/932] 正在爬取房源 3796459...
#
# 🔹[377/932] 正在爬取房源 3804795...
#
# 🔹[378/932] 正在爬取房源 3833796...
#
# 🔹[379/932] 正在爬取房源 3840321...
#
# 🔹[380/932] 正在爬取房源 3841266...
#
# 🔹[381/932] 正在爬取房源 3841339...
#
# 🔹[382/932] 正在爬取房源 3847617...
#
# 🔹[383/932] 正在爬取房源 3850766...
#
# 🔹[384/932] 正在爬取房源 3853993...
#
# 🔹[385/932] 正在爬取房源 3865210...
#
# 🔹[386/932] 正在爬取房源 3917964...
#
# 🔹[387/932] 正在爬取房源 3926355...
#
# 🔹[388/932] 正在爬取房源 3929712...
#
# 🔹[389/932] 正在爬取房源 3944495...
#
# 🔹[390/932] 正在爬取房源 3957639...
#
# 🔹[391/932] 正在爬取房源 3982031...
#
# 🔹[392/932] 正在爬取房源 4029316...
#
# 🔹[393/932] 正在爬取房源 4035170...
#
# 🔹[394/932] 正在爬取房源 4043288...
#
# 🔹[395/932] 正在爬取房源 4051748...
#
# 🔹[396/932] 正在爬取房源 4052965...
#
# 🔹[397/932] 正在爬取房源 4076501...
#
# 🔹[398/932] 正在爬取房源 4119684...
#
# 🔹[399/932] 正在爬取房源 4147932...
#
# 🔹[400/932] 正在爬取房源 4150731...
#
# 🔹[401/932] 正在爬取房源 4157853...
#
# 🔹[402/932] 正在爬取房源 4180798...
#
# 🔹[403/932] 正在爬取房源 4187658...
#
# 🔹[404/932] 正在爬取房源 4210531...
#
# 🔹[405/932] 正在爬取房源 4225575...
#
# 🔹[406/932] 正在爬取房源 4248769...
#
# 🔹[407/932] 正在爬取房源 4278312...
#
# 🔹[408/932] 正在爬取房源 4282186...
#
# 🔹[409/932] 正在爬取房源 4282686...
#
# 🔹[410/932] 正在爬取房源 4283460...
#
# 🔹[411/932] 正在爬取房源 4295087...
#
# 🔹[412/932] 正在爬取房源 4299280...
#
# 🔹[413/932] 正在爬取房源 4314620...
#
# 🔹[414/932] 正在爬取房源 4320334...
#
# 🔹[415/932] 正在爬取房源 4329449...
#
# 🔹[416/932] 正在爬取房源 4381773...
#
# 🔹[417/932] 正在爬取房源 4382332...
#
# 🔹[418/932] 正在爬取房源 4386276...
#
# 🔹[419/932] 正在爬取房源 4399067...
#
# 🔹[420/932] 正在爬取房源 4409509...
#
# 🔹[421/932] 正在爬取房源 4416539...
#
# 🔹[422/932] 正在爬取房源 4448285...
#
# 🔹[423/932] 正在爬取房源 4449764...
#
# 🔹[424/932] 正在爬取房源 4488692...
#
# 🔹[425/932] 正在爬取房源 4523624...
#
# 🔹[426/932] 正在爬取房源 4530308...
#
# 🔹[427/932] 正在爬取房源 4543149...
#
# 🔹[428/932] 正在爬取房源 4550468...
#
# 🔹[429/932] 正在爬取房源 4555659...
#
# 🔹[430/932] 正在爬取房源 4591819...
#
# 🔹[431/932] 正在爬取房源 4619390...
#
# 🔹[432/932] 正在爬取房源 4635416...
#
# 🔹[433/932] 正在爬取房源 4636051...
#
# 🔹[434/932] 正在爬取房源 4640869...
#
# 🔹[435/932] 正在爬取房源 4655656...
#
# 🔹[436/932] 正在爬取房源 4697911...
#
# 🔹[437/932] 正在爬取房源 4714161...
#
# 🔹[438/932] 正在爬取房源 4721743...
#
# 🔹[439/932] 正在爬取房源 4721855...
#
# 🔹[440/932] 正在爬取房源 4727758...
#
# 🔹[441/932] 正在爬取房源 4736237...
#
# 🔹[442/932] 正在爬取房源 4743636...
#
# 🔹[443/932] 正在爬取房源 4748130...
#
# 🔹[444/932] 正在爬取房源 4764531...
#
# 🔹[445/932] 正在爬取房源 4764819...
#
# 🔹[446/932] 正在爬取房源 4806556...
#
# 🔹[447/932] 正在爬取房源 4830755...
#
# 🔹[448/932] 正在爬取房源 4831146...
#
# 🔹[449/932] 正在爬取房源 4860508...
#
# 🔹[450/932] 正在爬取房源 4864384...
#
# 🔹[451/932] 正在爬取房源 4898741...
#
# 🔹[452/932] 正在爬取房源 4899798...
#
# 🔹[453/932] 正在爬取房源 4910572...
#
# 🔹[454/932] 正在爬取房源 4984717...
#
# 🔹[455/932] 正在爬取房源 5009826...
#
# 🔹[456/932] 正在爬取房源 5012728...
#
# 🔹[457/932] 正在爬取房源 5027842...
#
# 🔹[458/932] 正在爬取房源 5034576...
#
# 🔹[459/932] 正在爬取房源 5062713...
#
# 🔹[460/932] 正在爬取房源 5128825...
#
# 🔹[461/932] 正在爬取房源 5133110...
#
# 🔹[462/932] 正在爬取房源 5142163...
#
# 🔹[463/932] 正在爬取房源 5156433...
#
# 🔹[464/932] 正在爬取房源 5184303...
#
# 🔹[465/932] 正在爬取房源 5200740...
#
# 🔹[466/932] 正在爬取房源 5236285...
#
# 🔹[467/932] 正在爬取房源 5260611...
#
# 🔹[468/932] 正在爬取房源 5312713...
#
# 🔹[469/932] 正在爬取房源 5313835...
#
# 🔹[470/932] 正在爬取房源 5367709...
#
# 🔹[471/932] 正在爬取房源 5374067...
#
# 🔹[472/932] 正在爬取房源 5390933...
#
# 🔹[473/932] 正在爬取房源 5401946...
#
# 🔹[474/932] 正在爬取房源 5427607...
#
# 🔹[475/932] 正在爬取房源 5432591...
#
# 🔹[476/932] 正在爬取房源 5474153...
#
# 🔹[477/932] 正在爬取房源 5501544...
#
# 🔹[478/932] 正在爬取房源 5519881...
#
# 🔹[479/932] 正在爬取房源 5563422...
#
# 🔹[480/932] 正在爬取房源 5586553...
#
# 🔹[481/932] 正在爬取房源 5617321...
#
# 🔹[482/932] 正在爬取房源 5663570...
#
# 🔹[483/932] 正在爬取房源 5666746...
#
# 🔹[484/932] 正在爬取房源 5687572...
#
# 🔹[485/932] 正在爬取房源 5707655...
#
# 🔹[486/932] 正在爬取房源 5713368...
#
# 🔹[487/932] 正在爬取房源 5718834...
#
# 🔹[488/932] 正在爬取房源 5719013...
#
# 🔹[489/932] 正在爬取房源 5722319...
#
# 🔹[490/932] 正在爬取房源 5741450...
#
# 🔹[491/932] 正在爬取房源 5752944...
#
# 🔹[492/932] 正在爬取房源 5781996...
#
# 🔹[493/932] 正在爬取房源 5799439...
#
# 🔹[494/932] 正在爬取房源 5809024...
#
# 🔹[495/932] 正在爬取房源 5819801...
#
# 🔹[496/932] 正在爬取房源 5832006...
#
# 🔹[497/932] 正在爬取房源 5836359...
#
# 🔹[498/932] 正在爬取房源 5836389...
#
# 🔹[499/932] 正在爬取房源 5859999...
#
# 🔹[500/932] 正在爬取房源 5860701...
#
# 🔹[501/932] 正在爬取房源 5865168...
#
# 🔹[502/932] 正在爬取房源 5881435...
#
# 🔹[503/932] 正在爬取房源 5887152...
#
# 🔹[504/932] 正在爬取房源 5902525...
#
# 🔹[505/932] 正在爬取房源 5906728...
#
# 🔹[506/932] 正在爬取房源 5910570...
#
# 🔹[507/932] 正在爬取房源 5950023...
#
# 🔹[508/932] 正在爬取房源 5962744...
#
# 🔹[509/932] 正在爬取房源 5982570...
#
# 🔹[510/932] 正在爬取房源 5991024...
#
# 🔹[511/932] 正在爬取房源 5999569...
#
# 🔹[512/932] 正在爬取房源 6026663...
#
# 🔹[513/932] 正在爬取房源 6043774...
#
# 🔹[514/932] 正在爬取房源 6068622...
#
# 🔹[515/932] 正在爬取房源 6077424...
#
# 🔹[516/932] 正在爬取房源 6085243...
#
# 🔹[517/932] 正在爬取房源 6089697...
#
# 🔹[518/932] 正在爬取房源 6116302...
#
# 🔹[519/932] 正在爬取房源 6133157...
#
# 🔹[520/932] 正在爬取房源 6142913...
#
# 🔹[521/932] 正在爬取房源 6142928...
#
# 🔹[522/932] 正在爬取房源 6196745...
#
# 🔹[523/932] 正在爬取房源 6211859...
#
# 🔹[524/932] 正在爬取房源 6236389...
#
# 🔹[525/932] 正在爬取房源 6243633...
#
# 🔹[526/932] 正在爬取房源 6258741...
#
# 🔹[527/932] 正在爬取房源 6259402...
#
# 🔹[528/932] 正在爬取房源 6280751...
#
# 🔹[529/932] 正在爬取房源 6283404...
#
# 🔹[530/932] 正在爬取房源 6285243...
#
# 🔹[531/932] 正在爬取房源 6297430...
#
# 🔹[532/932] 正在爬取房源 6356312...
#
# 🔹[533/932] 正在爬取房源 6356866...
#
# 🔹[534/932] 正在爬取房源 6359921...
#
# 🔹[535/932] 正在爬取房源 6372597...
#
# 🔹[536/932] 正在爬取房源 6373767...
#
# 🔹[537/932] 正在爬取房源 6387811...
#
# 🔹[538/932] 正在爬取房源 6441316...
#
# 🔹[539/932] 正在爬取房源 6442389...
#
# 🔹[540/932] 正在爬取房源 6447564...
#
# 🔹[541/932] 正在爬取房源 6461959...
#
# 🔹[542/932] 正在爬取房源 6463787...
#
# 🔹[543/932] 正在爬取房源 6471162...
#
# 🔹[544/932] 正在爬取房源 6474026...
#
# 🔹[545/932] 正在爬取房源 6485103...
#
# 🔹[546/932] 正在爬取房源 6487791...
#
# 🔹[547/932] 正在爬取房源 6504823...
#
# 🔹[548/932] 正在爬取房源 6512505...
#
# 🔹[549/932] 正在爬取房源 6512602...
#
# 🔹[550/932] 正在爬取房源 6524982...
#
# 🔹[551/932] 正在爬取房源 6526164...
#
# 🔹[552/932] 正在爬取房源 6531893...
#
# 🔹[553/932] 正在爬取房源 6532120...
#
# 🔹[554/932] 正在爬取房源 6533303...
#
# 🔹[555/932] 正在爬取房源 6564456...
#
# 🔹[556/932] 正在爬取房源 6564747...
#
# 🔹[557/932] 正在爬取房源 6587565...
#
# 🔹[558/932] 正在爬取房源 6605182...
#
# 🔹[559/932] 正在爬取房源 6608540...
#
# 🔹[560/932] 正在爬取房源 6654255...
#
# 🔹[561/932] 正在爬取房源 6665729...
#
# 🔹[562/932] 正在爬取房源 6668354...
#
# 🔹[563/932] 正在爬取房源 6727439...
#
# 🔹[564/932] 正在爬取房源 6732776...
#
# 🔹[565/932] 正在爬取房源 6735459...
#
# 🔹[566/932] 正在爬取房源 6764251...
#
# 🔹[567/932] 正在爬取房源 6770676...
#
# 🔹[568/932] 正在爬取房源 6778319...
#
# 🔹[569/932] 正在爬取房源 6780631...
#
# 🔹[570/932] 正在爬取房源 6781132...
#
# 🔹[571/932] 正在爬取房源 6819536...
#
# 🔹[572/932] 正在爬取房源 6830331...
#
# 🔹[573/932] 正在爬取房源 6850043...
#
# 🔹[574/932] 正在爬取房源 6857675...
#
# 🔹[575/932] 正在爬取房源 6861769...
#
# 🔹[576/932] 正在爬取房源 6867245...
#
# 🔹[577/932] 正在爬取房源 6895794...
#
# 🔹[578/932] 正在爬取房源 6920719...
#
# 🔹[579/932] 正在爬取房源 6942100...
#
# 🔹[580/932] 正在爬取房源 6963313...
#
# 🔹[581/932] 正在爬取房源 6966341...
#
# 🔹[582/932] 正在爬取房源 6981284...
#
# 🔹[583/932] 正在爬取房源 6982667...
#
# 🔹[584/932] 正在爬取房源 7007415...
#
# 🔹[585/932] 正在爬取房源 7036515...
#
# 🔹[586/932] 正在爬取房源 7049460...
#
# 🔹[587/932] 正在爬取房源 7111455...
#
# 🔹[588/932] 正在爬取房源 7159415...
#
# 🔹[589/932] 正在爬取房源 7190115...
#
# 🔹[590/932] 正在爬取房源 7232162...
#
# 🔹[591/932] 正在爬取房源 7239681...
#
# 🔹[592/932] 正在爬取房源 7260210...
#
# 🔹[593/932] 正在爬取房源 7276869...
#
# 🔹[594/932] 正在爬取房源 7318827...
#
# 🔹[595/932] 正在爬取房源 7338230...
#
# 🔹[596/932] 正在爬取房源 7379564...
#
# 🔹[597/932] 正在爬取房源 7390801...
#
# 🔹[598/932] 正在爬取房源 7448305...
#
# 🔹[599/932] 正在爬取房源 7458963...
#
# 🔹[600/932] 正在爬取房源 7472412...
#
# 🔹[601/932] 正在爬取房源 7474662...
#
# 🔹[602/932] 正在爬取房源 7519976...
#
# 🔹[603/932] 正在爬取房源 7539137...
#
# 🔹[604/932] 正在爬取房源 7555385...
#
# 🔹[605/932] 正在爬取房源 7571471...
#
# 🔹[606/932] 正在爬取房源 7597331...
#
# 🔹[607/932] 正在爬取房源 7632775...
#
# 🔹[608/932] 正在爬取房源 7704803...
#
# 🔹[609/932] 正在爬取房源 7786634...
#
# 🔹[610/932] 正在爬取房源 7786801...
#
# 🔹[611/932] 正在爬取房源 7812608...
#
# 🔹[612/932] 正在爬取房源 7879063...
#
# 🔹[613/932] 正在爬取房源 7895182...
#
# 🔹[614/932] 正在爬取房源 7911798...
#
# 🔹[615/932] 正在爬取房源 7925449...
#
# 🔹[616/932] 正在爬取房源 7929179...
#
# 🔹[617/932] 正在爬取房源 7945458...
#
# 🔹[618/932] 正在爬取房源 7969191...
#
# 🔹[619/932] 正在爬取房源 7981030...
#
# 🔹[620/932] 正在爬取房源 8038640...
#
# 🔹[621/932] 正在爬取房源 8084800...
#
# 🔹[622/932] 正在爬取房源 8093694...
#
# 🔹[623/932] 正在爬取房源 8095648...
#
# 🔹[624/932] 正在爬取房源 8122504...
#
# 🔹[625/932] 正在爬取房源 8168988...
#
# 🔹[626/932] 正在爬取房源 8176659...
#
# 🔹[627/932] 正在爬取房源 8181348...
#
# 🔹[628/932] 正在爬取房源 8188948...
#
# 🔹[629/932] 正在爬取房源 8201117...
#
# 🔹[630/932] 正在爬取房源 8269677...
#
# 🔹[631/932] 正在爬取房源 8348686...
#
# 🔹[632/932] 正在爬取房源 8361053...
#
# 🔹[633/932] 正在爬取房源 8384069...
#
# 🔹[634/932] 正在爬取房源 8395119...
#
# 🔹[635/932] 正在爬取房源 8397086...
#
# 🔹[636/932] 正在爬取房源 8467413...
#
# 🔹[637/932] 正在爬取房源 8502593...
#
# 🔹[638/932] 正在爬取房源 8513183...
#
# 🔹[639/932] 正在爬取房源 8528299...
#
# 🔹[640/932] 正在爬取房源 8591687...
#
# 🔹[641/932] 正在爬取房源 8660698...
#
# 🔹[642/932] 正在爬取房源 8681273...
#
# 🔹[643/932] 正在爬取房源 8694687...
#
# 🔹[644/932] 正在爬取房源 8749341...
#
# 🔹[645/932] 正在爬取房源 8754550...
#
# 🔹[646/932] 正在爬取房源 8770120...
#
# 🔹[647/932] 正在爬取房源 8776772...
#
# 🔹[648/932] 正在爬取房源 8835898...
#
# 🔹[649/932] 正在爬取房源 8880908...
#
# 🔹[650/932] 正在爬取房源 8913666...
#
# 🔹[651/932] 正在爬取房源 8930278...
#
# 🔹[652/932] 正在爬取房源 8981648...
#
# 🔹[653/932] 正在爬取房源 9003963...
#
# 🔹[654/932] 正在爬取房源 9008887...
#
# 🔹[655/932] 正在爬取房源 9040505...
#
# 🔹[656/932] 正在爬取房源 9070642...
#
# 🔹[657/932] 正在爬取房源 9103703...
#
# 🔹[658/932] 正在爬取房源 9186603...
#
# 🔹[659/932] 正在爬取房源 9221506...
#
# 🔹[660/932] 正在爬取房源 9247120...
#
# 🔹[661/932] 正在爬取房源 9263993...
#
# 🔹[662/932] 正在爬取房源 9271262...
#
# 🔹[663/932] 正在爬取房源 9307157...
#
# 🔹[664/932] 正在爬取房源 9308904...
#
# 🔹[665/932] 正在爬取房源 9323377...
#
# 🔹[666/932] 正在爬取房源 9343414...
#
# 🔹[667/932] 正在爬取房源 9343949...
#
# 🔹[668/932] 正在爬取房源 9410136...
#
# 🔹[669/932] 正在爬取房源 9420691...
#
# 🔹[670/932] 正在爬取房源 9490497...
#
# 🔹[671/932] 正在爬取房源 9509889...
#
# 🔹[672/932] 正在爬取房源 9530785...
#
# 🔹[673/932] 正在爬取房源 9554582...
#
# 🔹[674/932] 正在爬取房源 9584580...
#
# 🔹[675/932] 正在爬取房源 9599423...
#
# 🔹[676/932] 正在爬取房源 9613135...
#
# 🔹[677/932] 正在爬取房源 9629614...
#
# 🔹[678/932] 正在爬取房源 9629640...
#
# 🔹[679/932] 正在爬取房源 9673745...
#
# 🔹[680/932] 正在爬取房源 9769837...
#
# 🔹[681/932] 正在爬取房源 9834151...
#
# 🔹[682/932] 正在爬取房源 9840061...
#
# 🔹[683/932] 正在爬取房源 9856921...
#
# 🔹[684/932] 正在爬取房源 9903960...
#
# 🔹[685/932] 正在爬取房源 9981202...
#
# 🔹[686/932] 正在爬取房源 9996040...
#
# 🔹[687/932] 正在爬取房源 10050359...
#
# 🔹[688/932] 正在爬取房源 10055894...
#
# 🔹[689/932] 正在爬取房源 10098198...
#
# 🔹[690/932] 正在爬取房源 10111606...
#
# 🔹[691/932] 正在爬取房源 10114567...
#
# 🔹[692/932] 正在爬取房源 10119487...
#
# 🔹[693/932] 正在爬取房源 10121407...
#
# 🔹[694/932] 正在爬取房源 10190247...
#
# 🔹[695/932] 正在爬取房源 10287267...
#
# 🔹[696/932] 正在爬取房源 10400021...
#
# 🔹[697/932] 正在爬取房源 10432232...
#
# 🔹[698/932] 正在爬取房源 10441222...
#
# 🔹[699/932] 正在爬取房源 10500911...
#
# 🔹[700/932] 正在爬取房源 10582203...
#
# 🔹[701/932] 正在爬取房源 10586291...
#
# 🔹[702/932] 正在爬取房源 10644438...
#
# 🔹[703/932] 正在爬取房源 10700796...
#
# 🔹[704/932] 正在爬取房源 10713194...
#
# 🔹[705/932] 正在爬取房源 10741538...
#
# 🔹[706/932] 正在爬取房源 10823505...
#
# 🔹[707/932] 正在爬取房源 11033260...
#
# 🔹[708/932] 正在爬取房源 11097614...
#
# 🔹[709/932] 正在爬取房源 11098408...
#
# 🔹[710/932] 正在爬取房源 11113843...
#
# 🔹[711/932] 正在爬取房源 11161348...
#
# 🔹[712/932] 正在爬取房源 11161861...
#
# 🔹[713/932] 正在爬取房源 11178448...
#
# 🔹[714/932] 正在爬取房源 11183366...
#
# 🔹[715/932] 正在爬取房源 11215477...
#
# 🔹[716/932] 正在爬取房源 11217131...
#
# 🔹[717/932] 正在爬取房源 11239298...
#
# 🔹[718/932] 正在爬取房源 11252596...
#
# 🔹[719/932] 正在爬取房源 11264941...
#
# 🔹[720/932] 正在爬取房源 11265870...
#
# 🔹[721/932] 正在爬取房源 11306602...
#
# 🔹[722/932] 正在爬取房源 11347669...
#
# 🔹[723/932] 正在爬取房源 11354028...
#
# 🔹[724/932] 正在爬取房源 11382530...
#
# 🔹[725/932] 正在爬取房源 11386080...
#
# 🔹[726/932] 正在爬取房源 11404636...
#
# 🔹[727/932] 正在爬取房源 11426523...
#
# 🔹[728/932] 正在爬取房源 11454092...
#
# 🔹[729/932] 正在爬取房源 11460770...
#
# 🔹[730/932] 正在爬取房源 11559431...
#
# 🔹[731/932] 正在爬取房源 11581438...
#
# 🔹[732/932] 正在爬取房源 11604860...
#
# 🔹[733/932] 正在爬取房源 11609099...
#
# 🔹[734/932] 正在爬取房源 11616153...
#
# 🔹[735/932] 正在爬取房源 11620756...
#
# 🔹[736/932] 正在爬取房源 11689351...
#
# 🔹[737/932] 正在爬取房源 11697661...
#
# 🔹[738/932] 正在爬取房源 11711052...
#
# 🔹[739/932] 正在爬取房源 11748044...
#
# 🔹[740/932] 正在爬取房源 11822995...
#
# 🔹[741/932] 正在爬取房源 11857316...
#
# 🔹[742/932] 正在爬取房源 11858660...
#
# 🔹[743/932] 正在爬取房源 11859556...
#
# 🔹[744/932] 正在爬取房源 11897715...
#
# 🔹[745/932] 正在爬取房源 11966081...
#
# 🔹[746/932] 正在爬取房源 12006505...
#
# 🔹[747/932] 正在爬取房源 12059101...
#
# 🔹[748/932] 正在爬取房源 12065591...
#
# 🔹[749/932] 正在爬取房源 12079751...
#
# 🔹[750/932] 正在爬取房源 12082536...
#
# 🔹[751/932] 正在爬取房源 12117800...
#
# 🔹[752/932] 正在爬取房源 12139525...
#
# 🔹[753/932] 正在爬取房源 12141525...
#
# 🔹[754/932] 正在爬取房源 12145656...
#
# 🔹[755/932] 正在爬取房源 12151249...
#
# 🔹[756/932] 正在爬取房源 12213244...
#
# 🔹[757/932] 正在爬取房源 12216213...
#
# 🔹[758/932] 正在爬取房源 12221842...
#
# 🔹[759/932] 正在爬取房源 12251301...
#
# 🔹[760/932] 正在爬取房源 12251311...
#
# 🔹[761/932] 正在爬取房源 12297515...
#
# 🔹[762/932] 正在爬取房源 12314549...
#
# 🔹[763/932] 正在爬取房源 12319764...
#
# 🔹[764/932] 正在爬取房源 12351923...
#
# 🔹[765/932] 正在爬取房源 12479300...
#
# 🔹[766/932] 正在爬取房源 12482590...
#
# 🔹[767/932] 正在爬取房源 12507039...
#
# 🔹[768/932] 正在爬取房源 12514682...
#
# 🔹[769/932] 正在爬取房源 12553513...
#
# 🔹[770/932] 正在爬取房源 12577304...
#
# 🔹[771/932] 正在爬取房源 12596322...
#
# 🔹[772/932] 正在爬取房源 12597756...
#
# 🔹[773/932] 正在爬取房源 12598630...
#
# 🔹[774/932] 正在爬取房源 12598924...
#
# 🔹[775/932] 正在爬取房源 12599072...
#
# 🔹[776/932] 正在爬取房源 12619145...
#
# 🔹[777/932] 正在爬取房源 12733599...
#
# 🔹[778/932] 正在爬取房源 12801514...
#
# 🔹[779/932] 正在爬取房源 12808277...
#
# 🔹[780/932] 正在爬取房源 12839333...
#
# 🔹[781/932] 正在爬取房源 12970674...
#
# 🔹[782/932] 正在爬取房源 13017542...
#
# 🔹[783/932] 正在爬取房源 13034385...
#
# 🔹[784/932] 正在爬取房源 13035842...
#
# 🔹[785/932] 正在爬取房源 13040996...
#
# 🔹[786/932] 正在爬取房源 13049566...
#
# 🔹[787/932] 正在爬取房源 13051355...
#
# 🔹[788/932] 正在爬取房源 13072405...
#
# 🔹[789/932] 正在爬取房源 13074889...
#
# 🔹[790/932] 正在爬取房源 13080195...
#
# 🔹[791/932] 正在爬取房源 13107969...
#
# 🔹[792/932] 正在爬取房源 13120829...
#
# 🔹[793/932] 正在爬取房源 13134714...
#
# 🔹[794/932] 正在爬取房源 13135409...
#
# 🔹[795/932] 正在爬取房源 13247212...
#
# 🔹[796/932] 正在爬取房源 13256599...
#
# 🔹[797/932] 正在爬取房源 13262950...
#
# 🔹[798/932] 正在爬取房源 13272633...
#
# 🔹[799/932] 正在爬取房源 13291327...
#
# 🔹[800/932] 正在爬取房源 13308006...
#
# 🔹[801/932] 正在爬取房源 13389882...
#
# 🔹[802/932] 正在爬取房源 13419312...
#
# 🔹[803/932] 正在爬取房源 13428614...
#
# 🔹[804/932] 正在爬取房源 13460110...
#
# 🔹[805/932] 正在爬取房源 13463110...
#
# 🔹[806/932] 正在爬取房源 13524423...
#
# 🔹[807/932] 正在爬取房源 13554855...
#
# 🔹[808/932] 正在爬取房源 13561575...
#
# 🔹[809/932] 正在爬取房源 13583998...
#
# 🔹[810/932] 正在爬取房源 13598808...
#
# 🔹[811/932] 正在爬取房源 13601323...
#
# 🔹[812/932] 正在爬取房源 13612108...
#
# 🔹[813/932] 正在爬取房源 13647474...
#
# 🔹[814/932] 正在爬取房源 13654387...
#
# 🔹[815/932] 正在爬取房源 13655161...
#
# 🔹[816/932] 正在爬取房源 13708567...
#
# 🔹[817/932] 正在爬取房源 13709435...
#
# 🔹[818/932] 正在爬取房源 13712862...
#
# 🔹[819/932] 正在爬取房源 13721713...
#
# 🔹[820/932] 正在爬取房源 13729010...
#
# 🔹[821/932] 正在爬取房源 13760261...
#
# 🔹[822/932] 正在爬取房源 13781229...
#
# 🔹[823/932] 正在爬取房源 13791396...
#
# 🔹[824/932] 正在爬取房源 13812250...
#
# 🔹[825/932] 正在爬取房源 13824148...
#
# 🔹[826/932] 正在爬取房源 13825117...
#
# 🔹[827/932] 正在爬取房源 13836709...
#
# 🔹[828/932] 正在爬取房源 13841525...
#
# 🔹[829/932] 正在爬取房源 13851468...
#
# 🔹[830/932] 正在爬取房源 13852643...
#
# 🔹[831/932] 正在爬取房源 13854126...
#
# 🔹[832/932] 正在爬取房源 13854467...
#
# 🔹[833/932] 正在爬取房源 13886949...
#
# 🔹[834/932] 正在爬取房源 13899162...
#
# 🔹[835/932] 正在爬取房源 13924175...
#
# 🔹[836/932] 正在爬取房源 13932749...
#
# 🔹[837/932] 正在爬取房源 13952349...
#
# 🔹[838/932] 正在爬取房源 13966822...
#
# 🔹[839/932] 正在爬取房源 14011549...
#
# 🔹[840/932] 正在爬取房源 14017497...
#
# 🔹[841/932] 正在爬取房源 14017892...
#
# 🔹[842/932] 正在爬取房源 14020792...
#
# 🔹[843/932] 正在爬取房源 14022135...
#
# 🔹[844/932] 正在爬取房源 14022661...
#
# 🔹[845/932] 正在爬取房源 14050092...
#
# 🔹[846/932] 正在爬取房源 14085220...
#
# 🔹[847/932] 正在爬取房源 14106265...
#
# 🔹[848/932] 正在爬取房源 14172232...
#
# 🔹[849/932] 正在爬取房源 14173331...
#
# 🔹[850/932] 正在爬取房源 14274504...
#
# 🔹[851/932] 正在爬取房源 14277750...
#
# 🔹[852/932] 正在爬取房源 14292407...
#
# 🔹[853/932] 正在爬取房源 14311105...
#
# 🔹[854/932] 正在爬取房源 14325757...
#
# 🔹[855/932] 正在爬取房源 14343204...
#
# 🔹[856/932] 正在爬取房源 14348158...
#
# 🔹[857/932] 正在爬取房源 14355043...
#
# 🔹[858/932] 正在爬取房源 14412467...
#
# 🔹[859/932] 正在爬取房源 14441994...
#
# 🔹[860/932] 正在爬取房源 14462366...
#
# 🔹[861/932] 正在爬取房源 14479187...
#
# 🔹[862/932] 正在爬取房源 14526096...
#
# 🔹[863/932] 正在爬取房源 14543325...
#
# 🔹[864/932] 正在爬取房源 14572858...
#
# 🔹[865/932] 正在爬取房源 14583283...
#
# 🔹[866/932] 正在爬取房源 14610348...
#
# 🔹[867/932] 正在爬取房源 14690112...
#
# 🔹[868/932] 正在爬取房源 14728813...
#
# 🔹[869/932] 正在爬取房源 14760457...
#
# 🔹[870/932] 正在爬取房源 14802237...
#
# 🔹[871/932] 正在爬取房源 14816635...
#
# 🔹[872/932] 正在爬取房源 14817368...
#
# 🔹[873/932] 正在爬取房源 14847200...
#
# 🔹[874/932] 正在爬取房源 14853175...
#
# 🔹[875/932] 正在爬取房源 14879214...
#
# 🔹[876/932] 正在爬取房源 14884099...
#
# 🔹[877/932] 正在爬取房源 14921039...
#
# 🔹[878/932] 正在爬取房源 14929937...
#
# 🔹[879/932] 正在爬取房源 15013026...
#
# 🔹[880/932] 正在爬取房源 15033074...
#
# 🔹[881/932] 正在爬取房源 15033626...
#
# 🔹[882/932] 正在爬取房源 15038140...
#
# 🔹[883/932] 正在爬取房源 15038670...
#
# 🔹[884/932] 正在爬取房源 15046252...
#
# 🔹[885/932] 正在爬取房源 15093623...
#
# 🔹[886/932] 正在爬取房源 15103827...
#
# 🔹[887/932] 正在爬取房源 15109768...
#
# 🔹[888/932] 正在爬取房源 15110564...
#
# 🔹[889/932] 正在爬取房源 15110844...
#
# 🔹[890/932] 正在爬取房源 15121800...
#
# 🔹[891/932] 正在爬取房源 15167502...
#
# 🔹[892/932] 正在爬取房源 15192210...
#
# 🔹[893/932] 正在爬取房源 15213109...
#
# 🔹[894/932] 正在爬取房源 15214101...
#
# 🔹[895/932] 正在爬取房源 15258535...
#
# 🔹[896/932] 正在爬取房源 15260123...
#
# 🔹[897/932] 正在爬取房源 15262729...
#
# 🔹[898/932] 正在爬取房源 15264411...
#
# 🔹[899/932] 正在爬取房源 15276959...
#
# 🔹[900/932] 正在爬取房源 15286319...
#
# 🔹[901/932] 正在爬取房源 15304003...
#
# 🔹[902/932] 正在爬取房源 15310556...
#
# 🔹[903/932] 正在爬取房源 15354556...
#
# 🔹[904/932] 正在爬取房源 15371462...
#
# 🔹[905/932] 正在爬取房源 15373310...
#
# 🔹[906/932] 正在爬取房源 15441407...
#
# 🔹[907/932] 正在爬取房源 15465365...
#
# 🔹[908/932] 正在爬取房源 15564639...
#
# 🔹[909/932] 正在爬取房源 15595655...
#
# 🔹[910/932] 正在爬取房源 15651912...
#
# 🔹[911/932] 正在爬取房源 15652115...
#
# 🔹[912/932] 正在爬取房源 15658599...
#
# 🔹[913/932] 正在爬取房源 15668614...
#
# 🔹[914/932] 正在爬取房源 15752260...
#
# 🔹[915/932] 正在爬取房源 15780515...
#
# 🔹[916/932] 正在爬取房源 15794631...
#
# 🔹[917/932] 正在爬取房源 15880053...
#
# 🔹[918/932] 正在爬取房源 15921637...
#
# 🔹[919/932] 正在爬取房源 15922131...
#
# 🔹[920/932] 正在爬取房源 15946060...
#
# 🔹[921/932] 正在爬取房源 15984970...
#
# 🔹[922/932] 正在爬取房源 16050056...
#
# 🔹[923/932] 正在爬取房源 16198996...
#
# 🔹[924/932] 正在爬取房源 16222778...
#
# 🔹[925/932] 正在爬取房源 16223096...
#
# 🔹[926/932] 正在爬取房源 16249620...
#
# 🔹[927/932] 正在爬取房源 16249820...
#
# 🔹[928/932] 正在爬取房源 16389105...
#
# 🔹[929/932] 正在爬取房源 16400107...
#
# 🔹[930/932] 正在爬取房源 16401179...
#
# 🔹[931/932] 正在爬取房源 16401807...
#
# 🔹[932/932] 正在爬取房源 16459632...
#
# ✅ 共提取 13989 条有回复的评论，已保存至：B(k,·)_host_reviews_written.csv

# %%
import pandas as pd

# === Step 1: Load the original host review data ===
# Replace with your local or actual file path
df = pd.read_csv("B(k,·)_host_reviews_written.csv")

# The file should contain the following fields:
# ['review_id', 'listing_id', 'host_id', 'created_at', 'response']

# === Step 2: Remove blank or invalid responses ===
df_clean = df.dropna(subset=['response'])  # Remove NaN
df_clean = df_clean[df_clean['response'].str.strip().astype(bool)]  # Remove empty strings

# Remove duplicate templates (same host_id writing the same response multiple times)
df_clean = df_clean.drop_duplicates(subset=['host_id', 'response'])

# Remove responses with fewer than five tokens
df_clean = df_clean[df_clean['response'].str.split().str.len() >= 5]

# === Step 3: Aggregate all response texts by host_id ===
bk_docs = (
    df_clean
    .groupby('host_id')['response']
    .apply(lambda texts: ' '.join(str(t) for t in texts))  # Concatenate into a single long document
    .reset_index()
    .rename(columns={'response': 'doc_text'})  # Output as host_id, doc_text
)

# === Step 4 (Optional): Save as a CSV file for modeling ===
bk_docs.to_csv("B_k_host_review_docs.csv", index=False, encoding='utf-8')

# === Step 5 (Optional): Print the first few rows for inspection ===
print(bk_docs.head())
# Out:
#    host_id                                           doc_text
# 0    97647  p Enjoy the Rhine! No recommend? Are we a vict...
# 1    98297  Thank you for your review and your stay  Sean!...
# 2    98647  Thanks for your kind words Hi Faisal,<br/>Than...
# 3    98844  Thank you for your review and your kind words ...
# 4   124245  ❤️❤️❤️❤️ Thank you so much ❤️❤️❤️ ❤️❤️❤️ Thank...
